# %%
#FOR CHAT CONVERSATION

from langchain_ollama import ChatOllama

# Initialize the model
llm = ChatOllama(
    model="gemma4:31b-cloud",
    temperature=0,
    
)

# Simple invocation
response = llm.invoke("Explain the concept of quantum entanglement in one sentence.")
print(response.content)
# Out:
# c:\Users\ACER\OneDrive\Desktop\Ollama_tutorial\ola_venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# Quantum entanglement is a phenomenon where two or more particles become linked in such a way that the state of one instantaneously influences the state of the other, regardless of the distance separating them.

# %%
# FOR NON CHAT EXECUTION
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="llama3.2:latest", temperature=0)

response = llm.invoke("The capital of France is")
print(response)
# Out:
# Paris.

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="embeddinggemma:300m",
)

# Embed a single query
query_result = embeddings.embed_query("What is LangChain?")
print(query_result)
# Out:
# [-0.12512533, 0.042090982, 0.021303432, -0.0051918053, 0.028913638, 0.03143775, 0.00158277, 0.023726486, -0.013615763, 0.009835337, -0.010132177, 0.0026639192, -0.013469625, -0.033371538, 0.01380119, 0.0061301175, 0.06461456, -0.027709141, -0.07751554, -0.0030924731, -0.024404954, -0.02318275, -0.050315604, -0.045951407, 0.022192994, 0.010218639, 0.04933629, -0.03188902, -0.005177743, -0.023245215, 0.043179646, -0.0045876717, -0.01232967, -0.023023965, 0.0727298, 0.039467774, 0.019801622, -0.015081235, -0.006075826, -0.022745797, -0.0058873915, 0.07605465, -0.0051235566, 0.0015793408, 0.024789272, -0.09636046, -0.049726706, -0.051003896, 0.023375647, 0.03635732, -0.034530126, -0.019291773, -0.08261264, 0.002648242, -0.029740134, -0.061145987, -0.046272237, -0.047656678, -0.024199693, 0.021472588, -0.06744683, 0.05790642, -0.010887301, -0.005074489, 0.061988372, 0.008233086, 0.026026921, -0.032706365, -0.014918057, 0.1764439, -0.02322177, -0.014356028, 0.01803039, 0.0053115194, 0.16757129, 0.074921064, -0.00017898847, -0.056382906, -0.058255326, 0.110046335, 0.00971236, 0.04370646, 0.0026380084, 0.0041228295, 0.1257111, -0.010521118, -0.059215948, 0.020447336, 0.0523082, -0.01956298, 0.038324874, -0.042583227, -0.055650253, 0.032305025, 0.016857997, -0.04801075, -0.029029412, -0.012899695, -0.05136975, 0.003909504, 0.02403007, 0.0053533097, 0.022392932, 0.10748186, 0.009156461, 0.0068837306, -0.06120539, -0.003924107, 0.017753249, 0.02077329, -0.047494527, 0.021093983, 0.014128544, -0.038068056, 0.04896701, 0.060253974, -0.0689675, 0.030489134, 0.036630694, 0