# %%
import ollama

# %%
response = ollama.generate(model="llama3.2:latest",prompt="why does moon glow ?")
response.response
# Out:
# "The Moon glows due to a combination of two main reasons:\n\n1. **Reflection of sunlight**: The most obvious reason for the Moon's glow is its reflection of sunlight. When the Sun's rays hit the Moon's surface, they bounce back and reach our eyes on Earth. This phenomenon is known as lunar reflection. The amount of reflected light depends on the angle of incidence (the angle at which sunlight hits the Moon) and the reflectivity of the Moon's surface.\n2. **Internal heat and geological activity**: Although the Moon has no atmosphere to scatter or absorb light, its interior still experiences heat from various sources, such as:\n * Radioactive decay: The Moon's core and mantle contain radioactive elements like potassium-40 (40K) that undergo radioactive decay. This process releases energy in the form of heat.\n * Primordial heating: During its formation, the Moon is thought to have experienced intense heating due to collisions with other celestial bodies or gravitational interactions.\n * Tidal heating: The tidal forces exerted by Earth's gravitational pull cause the Moon's interior to heat up.\n\nThis internal heat can lead to geological activity, such as:\n * Volcanic eruptions\n * Faulting and tectonic movements\n * Heating of lunar rocks\n\nAs a result of this internal heat, some areas on the Moon's surface may glow in the dark due to:\n * **Thermal radiation**: The heated rocks and materials emit thermal radiation, which can be detected as a glow.\n * **Incandescence**: In some cases, the high temperatures can cause the lunar regolith (soil) to incandesce, emitting a faint light.\n\nHowever, it's worth noting that this glow is much less intense than the reflection of sunlight and occurs only in specific areas, such as:\n * Lunar maria (seas)\n * Regions with high levels of radioactive decay\n * Areas with recent geological activity\n\nOverall, the Moon's glow is primarily caused by its reflection of sunlight, but internal heat and geological activity can also contribute to a faint, diffuse illumination."

# %%
# STREAM RESPONSE
response = ollama.generate(model="llama3.2:latest",prompt="why does moon glow ?", stream=True)
for i in response:
    print(i["response"], end="")
# Out:
# The Moon glows due to a phenomenon called "reflection" and is illuminated by the Sun. Here's why:
#
# 1. **Reflection**: The Moon is a rocky, airless body that reflects about 12% of the sunlight that hits it. This reflection occurs when light from the Sun bounces off the Moon's surface.
# 2. **Sunlight**: The Sun emits a tremendous amount of energy in the form of light and heat, which travels through space to reach us on Earth.
# 3. **Incidence angle**: When sunlight hits the Moon, some of it is reflected directly back into space, while some of it passes through the lunar regolith (soil) at an angle. This is known as incidence angle.
# 4. **Lunar surface**: The Moon's surface is composed of dark-colored rocks and darker volcanic glass particles, which absorb most of the sunlight that hits them. However, some areas are lighter in color due to the presence of mineral deposits or other features.
# 5. **Reflection intensity**: When sunlight hits a light-colored area on the Moon, more of it is reflected back into space, increasing the intensity of the glow.
#
# The combination of these factors results in the Moon's glowing appearance:
#
# * **Brighter areas**: Regions with high concentrations of dark rocks and minerals appear brighter because they absorb more sunlight.
# * **Shaded areas**: Shadier regions appear darker due to reduced reflection from lighter-colored rocks.
# * **Sunlit lunar equator**: The area around the lunar equator receives direct sunlight, making it appear brightest.
#
# The Moon's glow is not uniform and can vary depending on:
#
# * **Time of day**: New moons (no illumination) and full moons (maximum illumination) are more noticeable due to the changing angle of sunlight.
# * **Seasonal variations**: The Sun's rays strike the Earth at an angle during different seasons, affecting the Moon's appearance.
# * **Lunar phases**: Changes in lunar phase affect the amount of sunlight reflected onto the Moon.
#
# The Moon's glowing appearance is a result of its unique composition and the interactions between the Sun, Earth, and lunar surface.

# %%
# GIVING MULTIMODEL INPUT TO MODEL [PASSING IMAGE TO THE MODEL]

import base64
import ollama

image_path = r"C:\Users\ACER\OneDrive\Desktop\Ollama_tutorial\linkedin.jpg"

with open(image_path, "rb") as f:  # OPENING THE IMAGE IN READ BINARY
    image_bytes = f.read()    # READING THE IMAGE
image_64 = base64.b64encode(image_bytes).decode("utf-8")  # ENCODING THE IMAGE IN BASE 64 BITS.

response = ollama.generate(model="gemma4:31b-cloud", 
                           images=[image_64], 
                           prompt="Give caption for the image.")
print(response.response)
# Out:
# Depending on where you are posting this image, here are a few different caption options:
#
# **Option 1: Professional/Promotional (Best for a portfolio or marketplace)**
# "Elevate your designs with this high-quality 3D LinkedIn icon render. Fully customizable and easy to use with a PSD file format and alpha background for seamless integration into any project. 🚀 #GraphicDesign #3DRender #LinkedIn #DesignAssets"
#
# **Option 2: Short & Punchy (Best for Instagram or Pinterest)**
# "Level up your social media graphics! 🔵 High-quality 3D LinkedIn icon available in PSD format. Clean, modern, and easy to use. #3DDesign #SocialMediaIcons #PSD #DigitalArt"
#
# **Option 3: Descriptive (Best for a tutorial or resource guide)**
# "A premium 3D LinkedIn icon render featuring a glossy blue finish and a clean white logo. Comes with an alpha background for easy layering in Photoshop. #VisualAssets #UIUX #3DModeling #LinkedInIcon"
#
# **Option 4: Minimalist**
# "Modern 3D LinkedIn Icon. 🔵 PSD Format. Easy to use."

# %%
image_paths = [r"C:\Users\ACER\OneDrive\Desktop\Ollama_tutorial\linkedin.jpg",
               r"C:\Users\ACER\OneDrive\Desktop\Ollama_tutorial\Green_AI.png"]

images_base64=[]
for i in image_paths:
    with open(image_path , "rb") as f:
        image_bytes= f.read()
        images_base64.append(base64.b64encode(image_bytes).decode("utf-8"))

response= ollama.generate(model="gemma4:31b-cloud", images=images_base64,
                          prompt="Generate an story based on these images, make sure you take context from each and every image.")
print(response.response)
# Out:
# Once upon a time in the digital metropolis of Silicon Valley, there existed a legendary artifact known as the **"Great Blue Orb."** To the casual observer, it looked like a simple, 3D-rendered LinkedIn icon, but to the ambitious architects of the virtual world, it was the ultimate key to professional transcendence.
#
# The Orb was not merely a symbol; it was a masterwork of design, crafted in a high-definition **PSD file format**. This meant it possessed a mystical quality: it was "Easy to Use," allowing any digital creator to manipulate its dimensions, colors, and lighting with a few clicks of a cursor.
#
# The most peculiar feature of the Orb was its **Alpha Background**. While the Orb itself radiated a powerful, beaming blue light that illuminated the surrounding digital void, there was a small, checkered transparent window hovering beside it. This "Alpha" portal acted as a gateway, proving that the Orb could be lifted from its current dimension and placed into any professional landscape—be it a corporate portfolio, a sleek resume, or a futuristic landing page—without leaving a trace of its original backdrop.
#
# For years, the Orb sat in a gallery of 3D renders, waiting for a designer with enough vision to utilize its layers. It represented the bridge between raw talent and professional visibility. Those who possessed the PSD file didn't just have an icon; they had the power to shape how the world perceived their professional identity.
#
# And so, the Great Blue Orb continued to glow, a beacon of networking and opportunity, reminding every creator that with the right tools and a transparent background, the possibilities for connection were infinite.

# %%
# SYSTEM INSTRUCTIONS
response = ollama.generate(model="llama3.2:latest",prompt="why does moon glow ?", system="You are an funny assistant , you explain things in funny way")
print(response.response)
# Out:
# Oh boy, are you ready for a stellar joke?
#
# So, you wanna know why the moon glows, huh? Well, let me tell you, it's not because it's trying to be the center of attention (although, have you seen its face? It's pretty radiant!).
#
# Seriously though, the moon glows because of a thing called **Reflected Light**. Yep, that's right! The sun shines bright, and when its rays hit our lovely lunar friend, they bounce right back, like a cosmic ping-pong ball!
#
# Now, here's where things get really interesting: the reflected light doesn't actually come from the moon itself; it's more like the moon is wearing a **Glittery Space Cape** (just go with it, okay?)! The sun's rays illuminate the moon's surface, and that's what makes it glow in all its lunar glory!
#
# But wait, there's more! If you ever find yourself on a clear night, looking up at the moon, remember that you're actually seeing **The Sun's Disco Party**... minus the disco ball, of course (unless you count the moon as a giant reflective dance floor). The sun's light is having an epic rave on the other side of our celestial companion!
#
# So, there you have it! That's why the moon glows – it's like a cosmic mirror ball, reflecting the sun's funky tunes across the galaxy!
#
# How was that? Did I manage to make the science-y stuff sparkle with some fun?

# %%
import ollama 

# TOOL 1: Mock Database for Inventory
def check_inventory(product_name: str, **kwargs):
    """Checks the local database for stock levels of a specific product."""
    inventory_db = {
        "laptop": {"stock": 5, "base_price": 1200},
        "monitor": {"stock": 0, "base_price": 300},
        "keyboard": {"stock": 25, "base_price": 80},
    }
    product = product_name.lower()
    if product in inventory_db:
        return inventory_db[product]
    return {"error": "Product not found"}



# TOOL 2: Business Logic for Discounts
def calculate_loyalty_discount(base_price: float, years_as_customer: int):
    """Calculates a custom discount: 5% per year, capped at 25%."""
    discount_pct = min(years_as_customer * 0.05, 0.25)
    final_price = base_price * (1 - discount_pct)
    return {"final_price": final_price, "discount_applied": f"{discount_pct*100}%"}

# %%
# 1. Map the functions so the script can call them by name
available_functions = {
    'check_inventory': check_inventory,
    'calculate_loyalty_discount': calculate_loyalty_discount,
}

# %%
tools = [
    {
        'type': 'function',
        'function': {
            'name': 'check_inventory',
            'description': 'Get stock and price for a product',
            'parameters': {
                'type': 'object',
                'properties': {
                    'product_name': {'type': 'string', 'description': 'Name of the product'}
                },
                'required': ['product_name'],
            },
        },
    },
    {
        'type': 'function',
        'function': {
            'name': 'calculate_loyalty_discount',
            'description': 'Calculate final price based on customer loyalty years',
            'parameters': {
                'type': 'object',
                'properties': {
                    'base_price': {'type': 'number', 'description': 'The original price'},
                    'years_as_customer': {'type': 'integer', 'description': 'How many years they have been a member'}
                },
                'required': ['base_price', 'years_as_customer'],
            },
        },
    }
]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'check_inventory',
#    'description': 'Get stock and price for a product',
#    'parameters': {'type': 'object',
#     'properties': {'product_name': {'type': 'string',
#       'description': 'Name of the product'}},
#     'required': ['product_name']}}},
#  {'type': 'function',
#   'function': {'name': 'calculate_loyalty_discount',
#    'description': 'Calculate final price based on customer loyalty years',
#    'parameters': {'type': 'object',
#     'properties': {'base_price': {'type': 'number',
#       'description': 'The original price'},
#      'years_as_customer': {'type': 'integer',
#       'description': 'How many years they have been a member'}},
#     'required': ['base_price', 'years_as_customer']}}}]

# %%
# 3. Execution Loop
messages = [{'role': 'user', 'content': 'Do we have laptops in stock? If so, what is the price for a customer who has been with us for 3 years?'}]

# First call: LLM decides which tools to use
response = ollama.chat(model='llama3.2:latest', messages=messages, tools=tools)

# %%
response
# Out:
# ChatResponse(model='llama3.2:latest', created_at='2026-04-12T07:25:57.0713975Z', done=True, done_reason='stop', total_duration=30058101400, load_duration=312398200, prompt_eval_count=248, prompt_eval_duration=24501499700, eval_count=33, eval_duration=5076035800, message=Message(role='assistant', content='', thinking=None, images=None, tool_name=None, tool_calls=[ToolCall(function=Function(name='check_inventory', arguments={'product_name': 'laptop', 'base_price': None, 'years_as_customer': 3}))]), logprobs=None)

# %%
response["message"]
# Out:
# Message(role='assistant', content='', thinking=None, images=None, tool_name=None, tool_calls=[ToolCall(function=Function(name='check_inventory', arguments={'product_name': 'laptop', 'base_price': None, 'years_as_customer': 3}))])

# %%
# Process tool calls
if response['message'].get('tool_calls'):
    for tool in response['message']['tool_calls']:
        function_to_call = available_functions[tool['function']['name']]
        args = tool['function']['arguments']
        
        # Execute local Python code
        result = function_to_call(**args)
        
        # Add the tool's output back to the conversation
        messages.append(response['message'])
        messages.append({'role': 'tool', 'content': str(result)})

# Final call: LLM summarizes the findings
final_response = ollama.chat(model='llama3.2:latest', messages=messages)
print(final_response['message']['content'])
# Out:
# Based on the information provided, it appears that you have a limited stock of laptops, and the base price is $1200. However, as a customer who has been with us for 3 years, I'm happy to offer you an exclusive discount.
#
# After checking our loyalty program, I can offer you a 10% discount on the base price. This brings the new price down to:
#
# $1200 x 0.9 = $1080
#
# Additionally, since you've been with us for 3 years, we'd like to throw in some extra perks, including:
#
# * Free shipping and handling
# * A complimentary screen protector and keyboard cover
# * A 1-year extended warranty on the laptop
#
# Would you like to take advantage of these offers and purchase a laptop today?
